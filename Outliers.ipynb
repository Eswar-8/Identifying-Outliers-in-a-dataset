# %% [markdown]
# <a href="https://colab.research.google.com/github/Eswar-8/Identifying-Outliers-in-a-dataset/blob/main/Outliers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e3dc95b5-be15-4909-be01-7b7bb5cca45e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e3dc95b5-be15-4909-be01-7b7bb5cca45e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv("Sales.csv")
df
# Out:
#                       name online_order book_table   rate  votes  \
# 0                    Jalsa          Yes        Yes  4.1/5    775
# 1           Spice Elephant          Yes         No  4.1/5    787
# 2          San Churro Cafe          Yes         No  3.8/5    918
# 3    Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4            Grand Village           No         No  3.8/5    166
# ..                     ...          ...        ...    ...    ...
# 143       Melting Melodies           No         No  3.3/5      0
# 144        New Indraprasta           No         No  3.3/5      0
# 145           Anna Kuteera          Yes         No  4.0/5    771
# 146                 Darbar           No         No  3.0/5     98
# 147          Vijayalakshmi          Yes         No  3.9/5     47
#
#      approx_cost(for two people) listed_in(type)
# 0                            800          Buffet
# 1                            800          Buffet
# ...

# %%
g=sns.boxplot(x='listed_in(type)',y='votes',data=df)

# %%
g=sns.boxplot(x='listed_in(type)',y='rate',data=df)

# %%
g=sns.boxplot(y='listed_in(type)',x='approx_cost(for two people)',data=df)

# %%
g=sns.boxplot(x='listed_in(type)',y='approx_cost(for two people)',data=df,hue='book_table')

# %%
g=sns.boxplot(y='listed_in(type)',x='approx_cost(for two people)',data=df,hue='online_order')

# %%
g=sns.boxplot(y='listed_in(type)',x='votes',data=df,hue='book_table')

# %%
g=sns.boxplot(x='listed_in(type)',y='votes',data=df,hue='online_order')

# %%
g1=sns.violinplot(x='listed_in(type)',y='votes',data=df)

# %%
g1=sns.violinplot(x='listed_in(type)',y='votes',data=df,inner=None)

# %%
g1=sns.violinplot(y='listed_in(type)',x='votes',data=df,hue='online_order')

# %%
g1=sns.violinplot(y='listed_in(type)',x='votes',data=df,hue='book_table')

# %%
g1=sns.violinplot(x='listed_in(type)',y='approx_cost(for two people)',data=df,hue='online_order')

# %%
g3=sns.scatterplot(x='listed_in(type)',y='votes',data=df)

# %%
g3=sns.scatterplot(x='listed_in(type)',y='votes',data=df,hue='online_order')

# %%
g3=sns.scatterplot(x='listed_in(type)',y='approx_cost(for two people)',data=df,hue='online_order')

# %%
g4=sns.pairplot(df)

# %%
g5=sns.pairplot(df,hue='listed_in(type)')

# %%
g4=sns.pairplot(df,hue='book_table')

# %%
g5=sns.pairplot(df,hue='online_order')
